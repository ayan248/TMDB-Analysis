# %% [markdown]
# # Loading the dataset and brief overview

# %%
import pandas as pd
movies = pd.read_csv("E:\\TMDB_movie_dataset_v11.csv")

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1076311 entries, 0 to 1076310
# Data columns (total 24 columns):
#  #   Column                Non-Null Count    Dtype
# ---  ------                --------------    -----
#  0   id                    1076311 non-null  int64
#  1   title                 1076298 non-null  object
#  2   vote_average          1076311 non-null  float64
#  3   vote_count            1076311 non-null  int64
#  4   status                1076311 non-null  object
#  5   release_date          923585 non-null   object
#  6   revenue               1076311 non-null  int64
#  7   runtime               1076311 non-null  int64
#  8   adult                 1076311 non-null  bool
#  9   backdrop_path         293372 non-null   object
#  10  budget                1076311 non-null  int64
#  11  homepage              115979 non-null   object
#  12  imdb_id               590398 non-null   object
#  13  original_language     1076311 non-null  object
# ...

# %%
movies.head()
# Out:
#        id            title  vote_average  vote_count    status release_date  \
# 0   27205        Inception         8.364       34495  Released   2010-07-15
# 1  157336     Interstellar         8.417       32571  Released   2014-11-05
# 2     155  The Dark Knight         8.512       30619  Released   2008-07-16
# 3   19995           Avatar         7.573       29815  Released   2009-12-15
# 4   24428     The Avengers         7.710       29166  Released   2012-04-25
#
#       revenue  runtime  adult                     backdrop_path  ...  \
# 0   825532764      148  False  /8ZTVqvKDQ8emSGUEMjsS4yHAwrp.jpg  ...
# 1   701729206      169  False  /pbrkL804c8yAv3zBZR4QPEafpAR.jpg  ...
# 2  1004558444      152  False  /nMKdUUepR0i5zn0y1T4CsSB5chy.jpg  ...
# 3  2923706026      162  False  /vL5LR6WdxWPjLPFRLe133jXWsh5.jpg  ...
# 4  1518815515      143  False  /9BBTo63ANSmhC4e6r62OJFuK2GL.jpg  ...
#
#     original_title                                           overview  \
# ...

# %% [markdown]
# # Cleaning the data

# %%
movies = movies[['id', 'title', 'status', 'budget', 'runtime', 'vote_average', 'vote_count', 'popularity', 'revenue']]

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1076311 entries, 0 to 1076310
# Data columns (total 9 columns):
#  #   Column        Non-Null Count    Dtype
# ---  ------        --------------    -----
#  0   id            1076311 non-null  int64
#  1   title         1076298 non-null  object
#  2   status        1076311 non-null  object
#  3   budget        1076311 non-null  int64
#  4   runtime       1076311 non-null  int64
#  5   vote_average  1076311 non-null  float64
#  6   vote_count    1076311 non-null  int64
#  7   popularity    1076311 non-null  float64
#  8   revenue       1076311 non-null  int64
# dtypes: float64(2), int64(5), object(2)
# memory usage: 73.9+ MB

# %%
movies.dropna(inplace=True)

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1076298 entries, 0 to 1076310
# Data columns (total 9 columns):
#  #   Column        Non-Null Count    Dtype
# ---  ------        --------------    -----
#  0   id            1076298 non-null  int64
#  1   title         1076298 non-null  object
#  2   status        1076298 non-null  object
#  3   budget        1076298 non-null  int64
#  4   runtime       1076298 non-null  int64
#  5   vote_average  1076298 non-null  float64
#  6   vote_count    1076298 non-null  int64
#  7   popularity    1076298 non-null  float64
#  8   revenue       1076298 non-null  int64
# dtypes: float64(2), int64(5), object(2)
# memory usage: 82.1+ MB

# %%
movies = movies[(movies['budget'] > 0) & (movies['runtime'] > 0) & (movies['revenue'] > 0) & 
         (movies['vote_average'] > 0) & (movies['vote_count'] > 0) & (movies['popularity'] > 0)]

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10383 entries, 0 to 348631
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id            10383 non-null  int64
#  1   title         10383 non-null  object
#  2   status        10383 non-null  object
#  3   budget        10383 non-null  int64
#  4   runtime       10383 non-null  int64
#  5   vote_average  10383 non-null  float64
#  6   vote_count    10383 non-null  int64
#  7   popularity    10383 non-null  float64
#  8   revenue       10383 non-null  int64
# dtypes: float64(2), int64(5), object(2)
# memory usage: 811.2+ KB

# %% [markdown]
# # Defining features and labels

# %%
features = ['budget', 'runtime', 'vote_average', 'vote_count', 'popularity']
target = 'revenue'

x = movies[features]
y = movies[target]

# %% [markdown]
# # Splitting the data into training and testing sets

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=25)

# %% [markdown]
# # Standardizing Scaler

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
x_train_scaled = scaler.fit_transform(x_train)
x_test_scaled = scaler.transform(x_test)

# %% [markdown]
# # Linear Regression Model

# %% [markdown]
# ## Initializing and Training the model

# %%
from sklearn.linear_model import LinearRegression
lr_model = LinearRegression()
lr_model.fit(x_train_scaled, y_train)
# Out:
# LinearRegression()

# %% [markdown]
# ## Making predictions on the testing set

# %%
lr_y_pred = lr_model.predict(x_test_scaled)

# %% [markdown]
# ## Calculating performance of the model

# %%
from sklearn.metrics import r2_score
import numpy as np

lr_r2 = r2_score(y_test, lr_y_pred)

print(f"R-squared (R2): {lr_r2}")
# Out:
# R-squared (R2): 0.7119430952166041

# %% [markdown]
# # Polynomial Regression Model

# %% [markdown]
# ## Initializing and Training the model

# %%
from sklearn.preprocessing import PolynomialFeatures

poly = PolynomialFeatures(degree=2, include_bias=False)  
x_train_poly = poly.fit_transform(x_train_scaled)
x_test_poly = poly.transform(x_test_scaled)

poly_model = LinearRegression()
poly_model.fit(x_train_poly, y_train)
# Out:
# LinearRegression()

# %% [markdown]
# ## Making predictions on the testing set

# %%
poly_y_pred = poly_model.predict(x_test_poly)

# %% [markdown]
# ## Calculating performance of the model

# %%
poly_r2 = r2_score(y_test, poly_y_pred)

print(f"R-squared (R2): {poly_r2}")
# Out:
# R-squared (R2): 0.7792918490641412

# %% [markdown]
# # Decision Tree Regression Model

# %% [markdown]
# ## Initializing and Training the model

# %%
from sklearn.tree import DecisionTreeRegressor

dt_model = DecisionTreeRegressor()
dt_model.fit(x_train_scaled, y_train)
# Out:
# DecisionTreeRegressor()

# %% [markdown]
# ## Making predictions on the testing set

# %%
dt_y_pred = dt_model.predict(x_test_scaled)

# %% [markdown]
# ## Calculating performance of the model

# %%
dt_r2 = r2_score(y_test, dt_y_pred)

print(f"R-squared (R2): {dt_r2}")
# Out:
# R-squared (R2): 0.6335225872074769

# %% [markdown]
# # Random Forest Regression Model

# %% [markdown]
# ## Initializing and training the model

# %%
from sklearn.ensemble import RandomForestRegressor

rf_model = RandomForestRegressor()
rf_model.fit(x_train_scaled, y_train)
# Out:
# RandomForestRegressor()

# %% [markdown]
# ## Making predictions on the testing set

# %%
rf_y_pred = rf_model.predict(x_test_scaled)

# %% [markdown]
# ## Calculating performance of the model

# %%
rf_r2 = r2_score(y_test, rf_y_pred)

print(f"R-squared (R2): {rf_r2}")
# Out:
# R-squared (R2): 0.754433893752545

# %% [markdown]
# # Gradient Boosting Regression Model

# %% [markdown]
# ## Initializing and training the model

# %%
from sklearn.ensemble import GradientBoostingRegressor

gb_model = GradientBoostingRegressor(n_estimators=100, learning_rate=0.1, max_depth=3, random_state=25)
gb_model.fit(x_train_scaled, y_train)
# Out:
# GradientBoostingRegressor(random_state=25)

# %% [markdown]
# ## Making predictions on the testing set

# %%
gb_y_pred = gb_model.predict(x_test_scaled)

# %% [markdown]
# ## Calculating performance of the model

# %%
gb_r2 = r2_score(y_test, gb_y_pred)
print(f"Gradient Boosting R-squared (R2): {gb_r2}")
# Out:
# Gradient Boosting R-squared (R2): 0.7668276327436702

# %% [markdown]
# # KNN Regression Model

# %% [markdown]
# ## Initializing and training the model

# %%
from sklearn.neighbors import KNeighborsRegressor

knn_model = KNeighborsRegressor(n_neighbors=11)
knn_model.fit(x_train_scaled, y_train)
# Out:
# KNeighborsRegressor(n_neighbors=11)

# %% [markdown]
# ## Making predictions on the testing set

# %%
knn_y_pred = knn_model.predict(x_test_scaled)

# %% [markdown]
# ## Calculating performance of the model

# %%
knn_r2 = r2_score(y_test, knn_y_pred)
print(f"KNN R-squared (R2): {knn_r2}")
# Out:
# KNN R-squared (R2): 0.7426012009627931

# %% [markdown]
# # Plotting Graphs

# %% [markdown]
# ## Actual vs Predicted Revenue

# %%
import matplotlib.pyplot as plt

def plot_actual_vs_predicted(y_test, predictions, model_name):
    plt.figure(figsize=(10,6))
    plt.scatter(y_test, predictions, alpha=1, color='b')
    plt.plot([min(y_test), max(y_test)], [min(y_test), max(y_test)], color='r', linestyle='--') 
    plt.title(f'Actual vs Predicted Revenue ({model_name})')
    plt.xlabel('Actual Revenue')
    plt.ylabel('Predicted Revenue')
    plt.show()

# %% [markdown]
# ### For Linear Regression Model

# %%
plot_actual_vs_predicted(y_test, lr_y_pred, 'Linear Regression')

# %% [markdown]
# ### For Polynomial Regression Model

# %%
plot_actual_vs_predicted(y_test, poly_y_pred, 'Polynomial Regression')

# %% [markdown]
# ### For Decision Tree Regression Model

# %%
plot_actual_vs_predicted(y_test, dt_y_pred, 'Decision Tree Regression')

# %% [markdown]
# ### For Random Forest Regression Model

# %%
plot_actual_vs_predicted(y_test, rf_y_pred, 'Random Forest Regression')

# %% [markdown]
# ### For Gradient Boosting Regression Model

# %%
plot_actual_vs_predicted(y_test, gb_y_pred, 'Gradient Boosting')

# %% [markdown]
# ### For KNN Regression Model

# %%
plot_actual_vs_predicted(y_test, knn_y_pred, 'KNN Regression')

# %% [markdown]
# ## Feature Importance

# %%
def plot_feature_importance(model, model_name, x_train_scaled):
    feature_importances = model.feature_importances_
    features = x_train.columns
    
    importance_df = pd.DataFrame({'Feature': features, 'Importance': feature_importances})
    importance_df = importance_df.sort_values(by='Importance', ascending=False)

    plt.figure(figsize=(8, 6))
    plt.barh(importance_df['Feature'], importance_df['Importance'])
    plt.xlabel('Importance')
    plt.ylabel('Feature')
    plt.title(f'Feature Importance - {model_name}')
    plt.gca().invert_yaxis() 
    plt.show()

# %% [markdown]
# ### For Decision Tree Regression Model

# %%
plot_feature_importance(dt_model,'Decision Tree', x_train_scaled)

# %% [markdown]
# ### For Random Forest Regression Model

# %%
plot_feature_importance(rf_model, 'Random Forest', x_train_scaled)

# %% [markdown]
# ## R-squared vs K-Value for KNN Regression Model

# %%
k_values = range(1, 20)
errors = []
for k in k_values:
    knn = KNeighborsRegressor(n_neighbors=k)
    knn.fit(x_train_scaled, y_train)
    y_pred = knn.predict(x_test_scaled)
    errors.append(r2_score(y_test, y_pred))

plt.figure(figsize=(8, 6))
plt.plot(k_values, errors, marker='o', linestyle='-', color='purple')
plt.xlabel('Number of Neighbors (K)')
plt.ylabel('R-squared')
plt.title('R-squared vs K-Value')
plt.show()
